# %% [markdown]
# <a href="https://colab.research.google.com/github/maderadit22-lang/learning/blob/main/tugas_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = []
for i in range(10):
    n = float(input(f"Masukkan nilai ke-{i+1}: "))
    nilai.append(n)
# Out:
# Masukkan nilai ke-1: 40
# Masukkan nilai ke-2: 45
# Masukkan nilai ke-3: 50
# Masukkan nilai ke-4: 55
# Masukkan nilai ke-5: 60
# Masukkan nilai ke-6: 65
# Masukkan nilai ke-7: 70
# Masukkan nilai ke-8: 75
# Masukkan nilai ke-9: 85
# Masukkan nilai ke-10: 90

# %%
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)

print("Nilai tertinggi:", nilai_tertinggi)
print("Nilai terendah:", nilai_terendah)
# Out:
# Nilai tertinggi: 90.0
# Nilai terendah: 40.0

# %%
rata_rata = sum(nilai) / len(nilai)
print("Rata-rata nilai:", rata_rata)
# Out:
# Rata-rata nilai: 63.5

# %%
lulus = 0
tidak_lulus = 0

for n in nilai:
    if n >= 60:
        lulus += 1
    else:
        tidak_lulus += 1

print("Jumlah mahasiswa lulus:", lulus)
print("Jumlah mahasiswa tidak lulus:", tidak_lulus)
# Out:
# Jumlah mahasiswa lulus: 6
# Jumlah mahasiswa tidak lulus: 4

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.bar(["Tertinggi", "Terendah"], [nilai_tertinggi, nilai_terendah], color=["green", "red"])
plt.title("Perbandingan Nilai Tertinggi dan Terendah")
plt.ylabel("Nilai")
plt.show()

# %%
plt.figure()
plt.pie([lulus, tidak_lulus], labels=["Lulus", "Tidak Lulus"], autopct='%1.1f%%', colors=["blue","orange"])
plt.title("Persentase Kelulusan Mahasiswa")
plt.show()
